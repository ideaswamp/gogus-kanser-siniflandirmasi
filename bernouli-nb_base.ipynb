# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
dataset=pd.read_csv("breastCancer_processed.csv")
dataset.head()
# Out:
#     numara  yigin_kalinligi  hucre_boyutu_esbicim  hucre_sekil_esbicim  \
# 0  1000025                5                     1                    1
# 1  1002945                5                     4                    4
# 2  1015425                3                     1                    1
# 3  1016277                6                     8                    8
# 4  1017023                4                     1                    1
#
#    marjinal_yapisma  tek_epitel_hucre_boyut  ciplak_cekirdekler  \
# 0                 1                       2                   1
# 1                 5                       7                  10
# 2                 1                       2                   2
# 3                 1                       3                   4
# 4                 3                       2                   1
#
#    yumusak_kromatin  normal_nukleoli  mitoz  sinif
# 0                 3                1      1      0
# ...

# %%
x = dataset.drop(["sinif","numara"],axis=1).values
y = dataset["sinif"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.75, random_state = 9)

# %%
classifier = BernoulliNB()
classifier.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %%
y_pred_nb = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred_nb)
print(cm)
accuracy_nb = accuracy_score(y_test, y_pred_nb)
print(classification_report(y_test,y_pred_nb))
print(f"acc_score = {accuracy_nb}")
# Out:
# [[105   0]
#  [ 66   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       105
#            1       0.00      0.00      0.00        66
#
#     accuracy                           0.61       171
#    macro avg       0.31      0.50      0.38       171
# weighted avg       0.38      0.61      0.47       171
#
# acc_score = 0.6140350877192983
# /home/n4yuc4/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/n4yuc4/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # SKORLAR

# %% [markdown]
# ---
# ### train_size=0.60 random_state=5
# ```
# [[180   0]
#  [ 94   0]]
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.79       180
#            1       0.00      0.00      0.00        94
#
#     accuracy                           0.66       274
#    macro avg       0.33      0.50      0.40       274
# weighted avg       0.43      0.66      0.52       274
#
# acc_score = 0.656934306569343
# ```

# %% [markdown]
# ---
# ### train_size=0.60 random_state=9
# ```
# [[174   0]
#  [100   0]]
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78       174
#            1       0.00      0.00      0.00       100
#
#     accuracy                           0.64       274
#    macro avg       0.32      0.50      0.39       274
# weighted avg       0.40      0.64      0.49       274
#
# acc_score = 0.635036496350365
# ```

# %% [markdown]
# ---
# ### train_size=0.75 random_state=5
# ```
# [[114   0]
#  [ 57   0]]
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       114
#            1       0.00      0.00      0.00        57
#
#     accuracy                           0.67       171
#    macro avg       0.33      0.50      0.40       171
# weighted avg       0.44      0.67      0.53       171
#
# acc_score = 0.6666666666666666
# ```

# %% [markdown]
# ---
# ### train_size=0.75 random_state=9
# ```
# [[105   0]
#  [ 66   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       105
#            1       0.00      0.00      0.00        66
#
#     accuracy                           0.61       171
#    macro avg       0.31      0.50      0.38       171
# weighted avg       0.38      0.61      0.47       171
#
# acc_score = 0.6140350877192983
# ```
